# %%
from scipy import optimize


def f(x):
    return (x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.625*x - 5.625)

root = optimize.bisect(f, -9, -3)
root
# Out:
# -3.75

# %%
root = optimize.bisect(f, -1, -1)
root
# Out:
# -1.0

# %%
root = optimize.bisect(f, 0, 2)
root
# Out:
# 1.5
